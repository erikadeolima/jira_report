# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 22
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Análise de Valor como Desenvolvedora\n",
#       8     "Este notebook apresenta análises para demonstrar o valor agregado como desenvolvedora, usando os dados extraídos do Jira.\n"
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
#      13    "metadata": {},
#      14    "source": [
#      15     "import pandas as pd\n",
#      16     "import matplotlib.pyplot as plt\n",
#      17     "\n",
#      18     "# Carregar o CSV gerado pelo relatório Jira\n",
#      19     "df = pd.read_csv('/Users/erikalima/Documents/all_tasks_developed_by_erika_lima.csv')\n",
#      20     "df.head()"
#      21    ],
# ...
